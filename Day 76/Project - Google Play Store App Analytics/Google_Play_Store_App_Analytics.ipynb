# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('apps.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
df_apps.shape
df_apps.columns
df_apps.sample(5)
# Out:
#                                   App       Category  Rating  Reviews  \
# 4302           HipChat - beta version  COMMUNICATION    4.10     1035
# 9805                         Checkers           GAME    4.50   375996
# 2997  DX Simulation for X-aid Dx Belt         FAMILY    4.00       35
# 2255                       MC.Fitting   PRODUCTIVITY     NaN      130
# 310                      DT CLOTHINGS       SHOPPING    5.00        1
#
#       Size_MBs    Installs  Type  Price Content_Rating         Genres  \
# 4302     20.00      50,000  Free      0       Everyone  Communication
# 9805      3.30  10,000,000  Free      0       Everyone          Board
# 2997     48.00       5,000  Free      0       Everyone     Simulation
# 2255      3.40       1,000  Paid  $8.49       Everyone   Productivity
# 310       7.90          10  Free      0       Everyone       Shopping
#
#         Last_Updated Android_Ver
# 4302  August 7, 2018  4.1 and up
# 9805  August 6, 2018  4.1 and up
# ...

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
df_apps_new  = df_apps.drop(['Last_Updated', 'Android_Ver'], axis=1)
print(df_apps_new.columns)
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres'],
#       dtype='object')

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
print("Nan värden:", df_apps_new['Rating'].isna().sum().sum())

df_apps_new = df_apps_new.dropna(subset=['Rating'])

print("Nan värden:",df_apps_new['Rating'].isna().sum().sum())
# Out:
# Nan värden: 1474
# Nan värden: 0

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
instagram_rows = df_apps_new[df_apps_new['App'] == 'Instagram']["App"].count()
print("Rader för Instagram-appar:",instagram_rows)

print("Antal dubletter:",df_apps_new.duplicated().sum())

df_apps_new = df_apps_new.drop_duplicates()

print("Antal dubletter:",df_apps_new.duplicated().sum())
# Out:
# Rader för Instagram-appar: 4
# Antal dubletter: 476
# Antal dubletter: 0

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
df_apps_new.sort_values('Rating', ascending=False).head()
# Out:
#                         App Category  Rating  Reviews  Size_MBs Installs  \
# 186  Basics of Orthopaedics  MEDICAL    5.00        1      5.60       10
# 21      KBA-EZ Health Guide  MEDICAL    5.00        4     25.00        1
# 28                 Ra Ga Ba     GAME    5.00        2     20.00        1
# 47                  Mu.F.O.     GAME    5.00        2     16.00        1
# 237                EC Mover     GAME    5.00        5      4.60       10
#
#      Type  Price Content_Rating   Genres
# 186  Free      0       Everyone  Medical
# 21   Free      0       Everyone  Medical
# 28   Paid  $1.49       Everyone   Arcade
# 47   Paid  $0.99       Everyone   Arcade
# 237  Free      0       Everyone   Racing

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
df_apps_new.sort_values('Size_MBs', ascending=False).head()
# Out:
#                                   App   Category  Rating  Reviews  Size_MBs  \
# 9945                  Ultimate Tennis     SPORTS    4.30   183004    100.00
# 9944     Gangster Town: Vice District     FAMILY    4.30    65146    100.00
# 9943            Miami crime simulator       GAME    4.00   254518    100.00
# 9942   Talking Babsy Baby: Baby Games  LIFESTYLE    4.00   140995    100.00
# 10687          Hungry Shark Evolution       GAME    4.50  6074334    100.00
#
#           Installs  Type Price Content_Rating                  Genres
# 9945    10,000,000  Free     0       Everyone                  Sports
# 9944    10,000,000  Free     0     Mature 17+              Simulation
# 9943    10,000,000  Free     0     Mature 17+                  Action
# 9942    10,000,000  Free     0       Everyone  Lifestyle;Pretend Play
# 10687  100,000,000  Free     0           Teen                  Arcade

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
df_apps_new.sort_values('Reviews', ascending=False).head()

top50 = df_apps_new.sort_values('Reviews', ascending=False).head(50)


print("50 med högs betyg som är gratis/kostar:",top50['Type'].value_counts())
# Out:
# 50 med högs betyg som är gratis/kostar: Type
# Free    50
# Name: count, dtype: int64

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
import plotly.express as px


ratings_count = df_apps_new['Content_Rating'].value_counts()


fig = px.pie(
    values=ratings_count.values,
    names=ratings_count.index,
    title='Content Ratings'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
df_apps_new['Installs'].dtype

df_apps_new['Installs'] = df_apps_new['Installs'].str.replace(',', '').str.replace('+', '').str.replace('Free', '0')
df_apps_new['Installs'] = pd.to_numeric(df_apps_new['Installs'])
df_apps_new[df_apps_new['Installs'] >= 1_000_000_000].shape[0]
df_apps_new[df_apps_new['Installs'] == 1].shape[0]
df_apps_new['Installs'].value_counts().head()
# Out:
# Installs
# 1000000     1486
# 10000000    1130
# 100000      1110
# 10000        989
# 1000         699
# Name: count, dtype: int64

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %% [markdown]
# ### The most expensive apps sub $250

# %%
df_apps_new['Price'] = df_apps_new['Price'].str.replace('$', '')
df_apps_new['Price'] = pd.to_numeric(df_apps_new['Price'])


print("Top 20 dyraste appar:",df_apps_new.sort_values('Price', ascending=False).head(20))

df_apps_new = df_apps_new[df_apps_new['Price'] <= 250]

print("Appar kvar efter att ha tagit bort dyra appar:", df_apps_new.shape)


df_apps_new['Revenue_Estimate'] = df_apps_new['Price'] * df_apps_new['Installs']
top10 = df_apps_new.sort_values('Revenue_Estimate', ascending=False).head(10)
print("Top 10 högst intäkter:",top10)


games_count = top10[top10['Category'] == 'GAME'].shape[0]

print("Antal spel i top 10:", games_count)
# Out:
# Top 20 dyraste appar:                                  App   Category  Rating  Reviews  Size_MBs  \
# 3946        I'm Rich - Trump Edition  LIFESTYLE    3.60      275      7.30
# 1331          most expensive app (H)     FAMILY    4.30        6      1.50
# 1946  I am rich (Most expensive app)    FINANCE    4.10      129      2.70
# 2461              I AM RICH PRO PLUS    FINANCE    4.00       36     41.00
# 5765                       I am rich  LIFESTYLE    3.80     3547      1.80
# 3221                  I am Rich Plus     FAMILY    4.00      856      8.70
# 2394                      I am Rich!    FINANCE    3.80       93     22.00
# 4606               I Am Rich Premium    FINANCE    4.10     1867      4.70
# 3114                       I am Rich    FINANCE    4.30      180      3.80
# 3145              I am rich(premium)    FINANCE    3.50      472      0.94
# 2775                   I Am Rich Pro     FAMILY    4.40      201      2.70
# ...

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %%
cat_counts = df_apps_new['Category'].value_counts()

print("Top 10 kategorier med flest appar:")
print(cat_counts.head(10))

fig = px.bar(
    x=cat_counts.index,
    y=cat_counts.values,
    labels={'x': 'Kategori', 'y': 'Antal appar'},
    title="Konkurrens: Antal appar per kategori"
)
fig.show()
# Out:
# Top 10 kategorier med flest appar:
# Category
# FAMILY             1714
# GAME               1074
# TOOLS               733
# PRODUCTIVITY        334
# FINANCE             311
# PERSONALIZATION     310
# COMMUNICATION       307
# PHOTOGRAPHY         304
# MEDICAL             302
# LIFESTYLE           301
# Name: count, dtype: int64
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %%
cat_installs = df_apps_new.groupby('Category')['Installs'].sum().sort_values(ascending=True)

print("Top 10 kategorier med flest nerladdningar:")
print(cat_installs.tail(10))

fig = px.bar(
    x=cat_installs.values,
    y=cat_installs.index,
    orientation='h',
    labels={'x': 'Antal nerladdningar', 'y': 'Kategori'},
    title="Popularitet: Antal nerladdningar per kategori"
)

fig.show()
# Out:
# Top 10 kategorier med flest nerladdningar:
# Category
# NEWS_AND_MAGAZINES     5393110650
# VIDEO_PLAYERS          6221897200
# TRAVEL_AND_LOCAL       6361859300
# PHOTOGRAPHY            9721243130
# FAMILY                10041105490
# TOOLS                 11440724500
# PRODUCTIVITY          12463070180
# SOCIAL                12513841475
# COMMUNICATION         24152241530
# GAME                  31543862717
# Name: Installs, dtype: int64
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %%
import plotly.express as px

cat_data = df_apps_new.groupby('Category').agg(
    Apps=('App', 'count'),
    Installs=('Installs', 'sum')
).reset_index()

print(cat_data.head())

fig = px.scatter(
    cat_data,
    x='Apps',
    y='Installs',
    size='Installs',
    color='Category',
    hover_name='Category',
    title='Nedladdningar vs konkurrens'
)

fig.update_layout(
    yaxis=dict(type='log')
)

fig.show()
# Out:
#               Category  Apps    Installs
# 0       ART_AND_DESIGN    62   124233100
# 1    AUTO_AND_VEHICLES    73    53129800
# 2               BEAUTY    42    26916200
# 3  BOOKS_AND_REFERENCE   177  1916291655
# 4             BUSINESS   270   863518120
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
